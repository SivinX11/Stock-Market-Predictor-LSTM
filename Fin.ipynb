# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
plt.get_backend()

#Step 1. Importing the data

data_source = r'trainset.csv'
data = pd.read_csv(data_source)
data_source2 = r'testset.csv'
data2 = pd.read_csv(data_source2 )
print(data.head())
print(data2.head())
trainer = data
tester = data2


#Step 2. Feature scaling with Min Max Scaler

data_trainer = trainer.drop(['Date', 'Adj Close'], axis = 1)
sc = MinMaxScaler(feature_range = (0, 1))
data_trainer = sc.fit_transform(data_trainer)


#Step 3. Reshaping the training data into an acceptable form of the LSTM
 
X_train = []
y_train = []
for i in range(60, 1259):
    X_train.append(data_trainer[i-60:i])
    y_train.append(data_trainer[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)



#Step 4. Preparing the Sequential LSTM Model

model = Sequential()

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.0))

model.add(LSTM(units = 100, activation = 'relu', return_sequences = True))
model.add(Dropout(0.0))

model.add(LSTM(units = 120, activation = 'relu', return_sequences = True))
model.add(Dropout(0.0))

model.add(LSTM(units = 140))
model.add(Dropout(0.0))

model.add(Dense(units = 1))

model.summary()


#Step 5. Compiling the Model and implementing the learning algorithm

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 100, batch_size = 35)

#Step 6. Preparing the testing dataset, feature scaling and reshaping

past60 = trainer.tail(60)
final_trainer = past60.append(tester,ignore_index='True')
final_trainer = final_trainer.drop(['Date','Adj Close'],axis=1)
inputs = sc.transform(final_trainer)
X_test = []
y_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i])
    y_test.append(inputs[i,0])
X_test,y_test = np.array(X_test),np.array(y_test)


#Step 7. Predicting the data from the testing set

y_pred = model.predict(X_test)


#Step 8. Scaling back the data into Original Format

scale = 1/1.37903131e-03 #this is the factor obtained by the first value of y_test
y_pred = y_pred*scale
y_test = y_test*scale
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-01-02  357.385559  361.151062  355.959839  359.288177  359.288177
# 1  2013-01-03  360.122742  363.600128  358.031342  359.496826  359.496826
# 2  2013-01-04  362.313507  368.339294  361.488861  366.600616  366.600616
# 3  2013-01-07  365.348755  367.301056  362.929504  365.001007  365.001007
# 4  2013-01-08  365.393463  365.771027  359.874359  364.280701  364.280701
#
#     Volume
# 0  5115500
# 1  4666500
# 2  5562800
# 3  3332900
# 4  3373900
#          Date         Open         High          Low        Close  \
# 0  2018-01-02  1048.339966  1066.939941  1045.229980  1065.000000
# 1  2018-01-03  1064.310059  1086.290039  1063.209961  1082.479980
# 2  2018-01-04  1088.000000  1093.569946  1084.001953  1086.400024
# 3  2018-01-05  1094.000000  1104.250000  1092.000000  1102.229980
# 4  2018-01-08  1102.229980  1111.270020  1101.619995  1106.939941
#
#      Adj Close   Volume
# 0  1065.000000  1237600
# 1  1082.479980  1430200
# 2  1086.400024  1004600
# 3  1102.229980  1279100
# 4  1106.939941  1047600
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 60, 80)            27520
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 60, 80)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 60, 100)           72400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 60, 100)           0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 60, 120)           106080
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 60, 120)           0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 140)               146160
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 140)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 141
# =================================================================
# Total params: 352,301
# Trainable params: 352,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1199 samples
# Epoch 1/100
# 1199/1199 [==============================] - 10s 8ms/sample - loss: 0.0306
# Epoch 2/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0016
# Epoch 3/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0016
# Epoch 4/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0013
# Epoch 5/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0015
# Epoch 6/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0015
# Epoch 7/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0012
# Epoch 8/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0011
# Epoch 9/100
# 1199/1199 [==============================] - 5s 5ms/sample - loss: 0.0012
# Epoch 10/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 0.0011
# Epoch 11/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 9.6014e-04
# Epoch 12/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 7.8990e-04
# Epoch 13/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 7.5560e-04
# Epoch 14/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 7.2165e-04
# Epoch 15/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 7.3017e-04
# Epoch 16/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 6.8155e-04
# Epoch 17/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 7.2565e-04
# Epoch 18/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 7.6838e-04
# Epoch 19/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 5.7466e-04
# Epoch 20/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 5.1066e-04
# Epoch 21/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 5.8319e-04
# Epoch 22/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 6.2339e-04
# Epoch 23/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 4.3930e-04
# Epoch 24/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 3.8571e-04
# Epoch 25/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 4.5527e-04
# Epoch 26/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 3.1865e-04
# Epoch 27/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 3.1754e-04
# Epoch 28/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 3.8450e-04
# Epoch 29/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.9130e-04
# Epoch 30/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.4257e-04
# Epoch 31/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.3247e-04
# Epoch 32/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.5926e-04
# Epoch 33/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.5327e-04
# Epoch 34/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.0785e-04
# Epoch 35/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.6411e-04
# Epoch 36/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.1029e-04
# Epoch 37/100
# 1199/1199 [==============================] - 5s 5ms/sample - loss: 2.0524e-04
# Epoch 38/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 3.6207e-04
# Epoch 39/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.0723e-04
# Epoch 40/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.5976e-04
# Epoch 41/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.0159e-04
# Epoch 42/100
# 1199/1199 [==============================] - 5s 5ms/sample - loss: 1.9973e-04
# Epoch 43/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.8675e-04
# Epoch 44/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.6172e-04
# Epoch 45/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.2660e-04
# Epoch 46/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.2942e-04
# Epoch 47/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1951e-04
# Epoch 48/100
# 1199/1199 [==============================] - 5s 5ms/sample - loss: 1.4156e-04
# Epoch 49/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.7351e-04
# Epoch 50/100
# 1199/1199 [==============================] - 5s 5ms/sample - loss: 1.7118e-04
# Epoch 51/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1786e-04
# Epoch 52/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.4856e-04
# Epoch 53/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.4291e-04
# Epoch 54/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1975e-04
# Epoch 55/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.5480e-04
# Epoch 56/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.2754e-04
# Epoch 57/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.2776e-04
# Epoch 58/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.4517e-04
# Epoch 59/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.7187e-04
# Epoch 60/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.2722e-04
# Epoch 61/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1035e-04
# Epoch 62/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.3204e-04
# Epoch 63/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0990e-04
# Epoch 64/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1308e-04
# Epoch 65/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1462e-04
# Epoch 66/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.7045e-04
# Epoch 67/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.2115e-04
# Epoch 68/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 9.8112e-05
# Epoch 69/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0655e-04
# Epoch 70/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.3757e-04
# Epoch 71/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.5987e-04
# Epoch 72/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.8660e-04
# Epoch 73/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.8065e-04
# Epoch 74/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0959e-04
# Epoch 75/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.3816e-04
# Epoch 76/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 9.3818e-05
# Epoch 77/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 9.4798e-05
# Epoch 78/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1032e-04
# Epoch 79/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.3698e-04
# Epoch 80/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.1081e-04
# Epoch 81/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.4046e-04
# Epoch 82/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1560e-04
# Epoch 83/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 2.0638e-04
# Epoch 84/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1813e-04
# Epoch 85/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.3920e-04
# Epoch 86/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1623e-04
# Epoch 87/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 8.8332e-05
# Epoch 88/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0720e-04
# Epoch 89/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0292e-04
# Epoch 90/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 9.7360e-05
# Epoch 91/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0613e-04
# Epoch 92/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 9.0390e-05
# Epoch 93/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0357e-04
# Epoch 94/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1671e-04
# Epoch 95/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1023e-04
# Epoch 96/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.1604e-04
# Epoch 97/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 8.9533e-05
# Epoch 98/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 9.7723e-05
# Epoch 99/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.0981e-04
# Epoch 100/100
# 1199/1199 [==============================] - 6s 5ms/sample - loss: 1.8269e-04

# %%
#Step 9. Visualization of the model prediction
plt.figure(figsize=(16,5))
plt.plot(y_pred, color = 'blue', label = 'Predicted Stock Price')
plt.plot(y_test, color = 'green', label = 'Real Stock Price')
plt.title('Google Stock Market Predictor')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
